# %% [markdown]
# <a href="https://colab.research.google.com/github/sojeongpark0330/assignment/blob/master/Copy_of_takehomefile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](https://github.com/interviewquery/takehomes/blob/home_depot_1/home_depot_1/logo.png?raw=1)
#
# # Data Scientist and Sr. Data Scientist: Case Study (Core)
#
# ##  Overview
#
# In this exercise, you will be given data to create a gross sales forecast and prepare a presentation about your findings. You will have 4 hours to complete this. 90 minutes after you begin the case study, an assessor will check-in to see if you have any questions. Your presentation will follow the 4 hours given to prepare and will last a total of 30 minutes: 15 minutes to present your findings and 15 minutes for answering questions. Please read this guide thoroughly before beginning the exercise.
#
# We understand your desire to demonstrate your ability to use complex data science techniques, however, please be mindful of the 4 hour time constraint! In your presentation, we encourage you to highlight additional techniques and/or areas of exploration you would pursue given more time. Keep in mind, for us to fully evaluate your performance, a completed assignment that can thoughtfully communicate the results is needed.
#
# ### Background
#
# As a Data Scientist, you are expected to demonstrate expertise in the following areas:
#
# - Successful interpretation of data and feature engineering.
#
# - Data cleansing and outlier control.
#
# - Making data-driven recommendations.
#
# - Communicating your recommendations in a clear and effective manner.
#
# The intent of this case study is to evaluate you on these four key aptitudes. In evaluating your performance, we will be assessing both the quantitative and qualitative elements of your answer. We look forward to reviewing your results.
#
# ### Problem Set Up
#
# You have recently been asked to develop a monthly forecasting model for a new product category to be sold within our stores. The data available is modeled after a subset of operational data that we use at Home Depot when confronting a problem of this nature. You are allowed and encouraged to answer this problem in whatever way best suits you and highlights your talents (e.g., program or software of choice). Note: that the scenario outlined below is fictitious and should NOT be construed as indicating The Home Depot has any plans to change its business.
#
# ### Scenario
#
# Beginning next year, The Home Depot will begin to carry work apparel. Having never merchandised products of this type before, it is your responsibility to determine how customer demand will respond to this assortment expansion on a monthly basis. Our merchandising team has provided you an annual estimate of how much they expect to sell next year. You will need to articulate the likely financial impact to monthly sales of incorporating this new product line.
#
# **To be successful on this assignment, you must:**
#
# - Create a monthly FY 2020 sales forecast for the new products.
#
# - Create a monthly FY 2020 total sales forecast for all product categories, including the new apparel category.
#
# ### Expectations
#
# Successful completion of this exercise will require that you provide the following:
#
# - Any code or spreadsheets used to create your recommendation including annotated comments on what was done.
#
# - Any modified datasets that you produce.
#
# - Any relevant visualizations you created (e.g., charts, graphs, etc.).
#
# - A non-technical presentation of your findings.
#
# All materials provided should be sufficient to replicate your approach. All data provided to the assessors is sufficient to complete this exercise - no external data should be needed or used.
#
#
# ### Data Model
#
# |**Table**|**Definition**|
# | :-: | :-: |
# |`HISTORICAL_CUSTOMER_SALES`|Product-level monthly sales (i.e. demand) for existing products carried by The Home Depot as well as new products.|
# |`MONTHLY_SALES_ESTIMATE`|By category, the historical estimate that has been provided for existing categories.|
# |`CURRENT_PRODUCT_ATTRIBUTES`|Product-level attributes for the existing products assorted at The Home Depot (e.g. dimensional data, space allocation, price, cost, etc.)|
#
#
#
# For each table provided, please consult the following definitions for the columns within each table:
#
# |`HISTORICAL_CUSTOMER_SALES`|  |
# | :-: | :-: |
# |**Column**|**Definition**|
# |`PRODUCT_ID`|Unique identifier for the product.|
# |`FISCAL_MONTH_END_DT`|The last day of the fiscal month.|
# |`GROSS_SALES_QTY`|The gross sales (in units) recorded for the entirety of the month.|
# |`NET_SALES_QTY`|The difference between gross sales and returns, in units.|
#
#
# |`MONTHLY_SALES_ESTIMATE`| |
# | :-: | :-: |
# |**Column**|**Definition**|
# |`PRODUCT_CATEGORY_NAME`|Name of the category of products to which the product belongs.|
# |`FISCAL_YEAR`|Fiscal year for the entry.|
# |`FISCAL_MONTH_END_DT`|The last day of the fiscal month.|
# |`GROSS_SALES_ESTIMATE`|The gross sales estimate, in dollars, for the entirety of the month.|
#
#
#
#
# |`PRODUCT_ATTRIBUTES`| |
# | :-: | :-: |
# |**Column**|**Definition**|
# |`PRODUCT_ID`|Unique identifier for the product.|
# |`PRODUCT_CATEGORY_NAME`|Name of the category of products to which the product belongs.|
# |`PRODUCT_NAME`|Product displayed name to the customer.|
# |`CURR_RETL_PRICE`|The current price of a single sellable unit of the product at a store.|
# |`HEIGHT`|Height of the individual product as it is merchandised on the shelf.|
# |`WIDTH`|Width of the individual product as it is merchandised on the shelf.|
# |`DEPTH`|Depth of the individual product as it is merchandised on the shelf.|
# |`WEIGHT`|Weight of the individual product as it is merchandised on the shelf.|
# |`HAZMAT_FLG`|Indicates whether or not the product contains hazardous materials.|
# |`MERCURY_FLG`|Indicates whether or not the product contains mercury.|
# |`ELECTRIC_FLG`|Indicates whether or not the product is electrically powered.|
# |`CHEMICAL_FLG`|Indicates whether or not the product is a chemical.|
# |`LIQUID_FLG`|Indicates whether or not the product is a liquid.|
# |`AEROSOL_FLG`|Indicates whether or not the product is an aerosol.|
# |`PESTICIDE_FLG`|Indicates whether or not the product is a pesticide.|
# |`BATTERY_FLG`|Indicates whether or not the product includes a battery.|
# |`GAS_FLG`|Indicates whether or not the product is gas powered.|
# |`MARKETING_COPY`|Text that appears on the website describing the product.|
#
#
#
# |`FISCAL_CALENDAR`|  |
# | :-: | :-: |
# |**Column**|**Definition**|
# |`FISCAL_YEAR`|Fiscal year|
# |`FISCAL_MONTH_NBR`|Month of the fiscal year.  1 = February, 12 = January.|
# |`FISCAL_MONTH_BEGIN_DT`|The first day of the fiscal month.|
# |`FISCAL_MONTH_END_DT`|The last day of the fiscal month.|
#
#
#
#
# ![](https://cdn.mathpix.com/cropped/2022_09_15_1be9766c3a4f334ce49fg-5.jpg?height=1296&width=1895&top_left_y=187&top_left_x=104)

# %% [markdown]
# ## Answer Sheet
#
#
# This worksheet constitutes the **quantitative** component of your assessment.
#
# The 2020 Forecast (in Dollars) For **ONLY** the new products:
#
# |**Fiscal Month**|**Month Ending Date**|**Winter Work Jacket**|**Winter Boot**|**Wool Hat**|
# | :-: | :-: | :-: | :-: | :-: |
# |February|3/1/2020||||
# |March|3/29/2020||||
# |April|5/3/2020||||
# |May|5/31/2020||||
# |June|6/28/2020||||
# |July|8/2/2020||||
# |August|8/30/2020||||
# |September|9/27/2020||||
# |October|11/1/2020||||
# |November|11/29/2020||||
# |December|12/27/2020||||
# |January|1/31/2021||||
#
# The 2020 Forecast (in Dollars) for **ALL PRODUCTS** including the new products:
#
# |**Fiscal Month**|**Month Ending Date**|**Total Monthly Forecast (in Millions of $)**|
# | :-: | :-: | :-: |
# |February|3/1/2020||
# |March|3/29/2020||
# |April|5/3/2020||
# |May|5/31/2020||
# |June|6/28/2020||
# |July|8/2/2020||
# |August|8/30/2020||
# |September|9/27/2020||
# |October|11/1/2020||
# |November|11/29/2020||
# |December|12/27/2020||
# |January|1/31/2021||

# %%
# !git clone --branch home_depot_1 https://github.com/interviewquery/takehomes.git
# %cd takehomes/home_depot_1
# !if [[ $(ls *.zip) ]]; then unzip *.zip; fi
# !ls
# Out:
# Cloning into 'takehomes'...
# remote: Enumerating objects: 1768, done.
# remote: Counting objects: 100% (576/576), done.
# remote: Compressing objects: 100% (455/455), done.
# remote: Total 1768 (delta 169), reused 481 (delta 120), pack-reused 1192
# Receiving objects: 100% (1768/1768), 297.30 MiB | 10.52 MiB/s, done.
# Resolving deltas: 100% (619/619), done.
# /content/takehomes/home_depot_1
# ls: cannot access '*.zip': No such file or directory
# FISCAL_CALENDAR.csv	       MONTHLY_SALES_ESTIMATE.csv
# HISTORICAL_CUSTOMER_SALES.csv  PRODUCT_ATTRIBUTES.csv
# logo.png		       takehomefile.ipynb

# %%
# Write your code here
#import libaries
import pandas as pd
import numpy as np
from matplotlib.ticker import StrMethodFormatter, NullFormatter
import matplotlib.pyplot as plt
import seaborn as sns

#import csv file
fiscal_calender = pd.read_csv('./FISCAL_CALENDAR.csv')
historical_customer = pd.read_csv('./HISTORICAL_CUSTOMER_SALES.csv')
monthly_sales_estimate = pd.read_csv('./MONTHLY_SALES_ESTIMATE.csv')
product_attributes = pd.read_csv('./PRODUCT_ATTRIBUTES.csv')

# %%
#check each tables' information
print('fiscal_calender_table')
print(fiscal_calender.info())
print('historical_customer_table')
print(historical_customer.info())
print('monthly_sales_estimate_table')
print(monthly_sales_estimate.info())
print('product_attributes_table')
print(product_attributes.info())
# Out:
# fiscal_calender_table
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FISCAL_YEAR            48 non-null     int64
#  1   FISCAL_MONTH_NBR       48 non-null     int64
#  2   FISCAL_MONTH_BEGIN_DT  48 non-null     object
#  3   FISCAL_MONTH_END_DT    48 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.6+ KB
# None
# historical_customer_table
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6273 entries, 0 to 6272
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PRODUCT_ID           6273 non-null   int64
#  1   FISCAL_MONTH_END_DT  6273 non-null   object
#  2   GROSS_SALES_QTY      6273 non-null   int64
#  3   NET_SALES_QTY        6273 non-null   int64
# dtypes: int64(3), object(1)
# ...

# %% [markdown]
# # **1.Data Processing**
#
# *   Before to analyze whole trend of sales, I am going to clean and merge all datasets.

# %%
#PRODUCT_ID is the key column, before merge tables, I would like to check data type of each tables
#check each tables' information
table_list = [fiscal_calender,historical_customer,monthly_sales_estimate,product_attributes]

for table_name in table_list:
  print(table_name.dtypes,sep='\n\n')
# Out:
# FISCAL_YEAR               int64
# FISCAL_MONTH_NBR          int64
# FISCAL_MONTH_BEGIN_DT    object
# FISCAL_MONTH_END_DT      object
# dtype: object
# PRODUCT_ID              int64
# FISCAL_MONTH_END_DT    object
# GROSS_SALES_QTY         int64
# NET_SALES_QTY           int64
# dtype: object
# PRODUCT_CATEGORY_NAME    object
# FISCAL_YEAR               int64
# FISCAL_MONTH_NBR          int64
# FISCAL_MONTH_END_DT      object
# GROSS_SALES_ESTIMATE     object
# dtype: object
# PRODUCT_ID                object
# PRODUCT_CATEGORY_NAME     object
# PRODUCT_NAME              object
# CURR_RETL_PRICE          float64
# HEIGHT                   float64
# WIDTH                    float64
# DEPTH                    float64
# HAZMAT_FLG                object
# MERCURY_FLG               object
# ELECTRIC_FLG              object
# CHEMICAL_FLG              object
# LIQUID_FLG                object
# AEROSOL_FLG               object
# PESTICIDE_FLG             object
# ...

# %%
# Need to change TABLE historical_customer PRODUCT_ID INT -> STR
historical_customer['PRODUCT_ID'] = historical_customer['PRODUCT_ID'].astype(str)

# %%
#check null values percentage
product_attributes.isnull().mean() * 100
# Out:
# PRODUCT_ID                0.000000
# PRODUCT_CATEGORY_NAME     0.000000
# PRODUCT_NAME              0.000000
# CURR_RETL_PRICE           0.000000
# HEIGHT                   62.702703
# WIDTH                    62.702703
# DEPTH                    62.702703
# HAZMAT_FLG               61.081081
# MERCURY_FLG              61.081081
# ELECTRIC_FLG             61.081081
# CHEMICAL_FLG             61.081081
# LIQUID_FLG               61.081081
# AEROSOL_FLG              61.081081
# PESTICIDE_FLG            61.081081
# BATTERY_FLG              61.081081
# GAS_FLG                  61.081081
# MARKETING_COPY           25.405405
# dtype: float64

# %%
# I will choose columns which have no null values(PRODUCT_ID,PRODUCT_CATEGORY_NAME,PRODUCT_NAME,CURR_RETL_PRICE)
#drop null value
product_attributes = product_attributes[['PRODUCT_ID','PRODUCT_CATEGORY_NAME','PRODUCT_NAME','CURR_RETL_PRICE']]

# %%
# merge product_attribute & historcial_custoemr
df_hist_product = pd.merge(historical_customer, product_attributes, how='left',on ='PRODUCT_ID')

# %%
# merge df_hist_product & fiscal_calender
df_all = pd.merge(df_hist_product, fiscal_calender, how = 'left', on ='FISCAL_MONTH_END_DT')
df_all.head()
# Out:
#   PRODUCT_ID FISCAL_MONTH_END_DT  GROSS_SALES_QTY  NET_SALES_QTY  \
# 0     618170           1 12 2019            28488          26951
# 1     618170           2 06 2019            37185          35341
# 2     618170          29 04 2018            34340          32829
# 3     618170          29 10 2017            31832          30257
# 4     618170          24 09 2017            31956          30422
#
#   PRODUCT_CATEGORY_NAME                        PRODUCT_NAME  CURR_RETL_PRICE  \
# 0           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE            3.890
# 1           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE            3.890
# 2           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE            3.890
# 3           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE            3.890
# 4           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE            3.890
#
#    FISCAL_YEAR  FISCAL_MONTH_NBR FISCAL_MONTH_BEGIN_DT
# 0         2019                10             4 11 2019
# ...

# %%
#Going to select columns that are useful for analysis and add new value columns to calculate actual profit value.
df_all = df_all[['PRODUCT_ID','PRODUCT_CATEGORY_NAME', 'PRODUCT_NAME', 'CURR_RETL_PRICE', 'FISCAL_YEAR', 'FISCAL_MONTH_NBR', 'GROSS_SALES_QTY',
       'NET_SALES_QTY','FISCAL_MONTH_END_DT']]
df_all['GROSS_PROFIT'] = df_all['CURR_RETL_PRICE'] * df_all['GROSS_SALES_QTY']
df_all['NET_PROFIT'] = df_all['CURR_RETL_PRICE'] * df_all['NET_SALES_QTY']

# %%
df_all.head()
# Out:
#   PRODUCT_ID PRODUCT_CATEGORY_NAME                        PRODUCT_NAME  \
# 0     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 1     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 2     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 3     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 4     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
#
#    CURR_RETL_PRICE  FISCAL_YEAR  FISCAL_MONTH_NBR  GROSS_SALES_QTY  \
# 0             3.89         2019                10            28488
# 1             3.89         2019                 4            37185
# 2             3.89         2018                 3            34340
# 3             3.89         2017                 9            31832
# 4             3.89         2017                 8            31956
#
#    NET_SALES_QTY  GROSS_PROFIT  NET_PROFIT
# 0          26951     110818.32   104839.39
# 1          35341     144649.65   137476.49
# ...

# %% [markdown]
# # **2. Overall Sale Trend from all product**
#
#
# *   Going to analyze yearly, monthly amount of sale

# %%
# making fucntion for group by dataframe
def create_df(df, cat):
    '''Create dataframes with desired groupings'''
    group_df = df.groupby(cat).agg({'GROSS_PROFIT': 'mean', 'NET_PROFIT':'mean', 'CURR_RETL_PRICE':'mean'})
    return group_df

# making fucntion for graphs
def create_plots(df, num, cat, time):

    '''Create barplots for the specified dataframe'''
    # Define the subplots
    fig, ax = plt.subplots(nrows=num, figsize=(30, 20))
    #ax.get_xaxis().get_major_formatter().set_scientific(False)


    # Create the barplots
    for col in range(len(CoI)):
        sns.barplot(x=cat, y=df[CoI[col]], hue= time, data=df, ax=ax[col])
        ax[col].set_xticklabels(labels=df[cat].unique(), rotation=45)
        ax[col].legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
        plt.tight_layout()

# %% [markdown]
# **2-1.Yearly Profit Trend**
#
#
# *   GROSS_SALES_PROFIT is getting lower compared to 2017 but NET SALE PROFIT doesn't seem to be changed. That is because average price of products has been increased.

# %%
# Yearly sale trend
group_df = create_df(df_all, ['FISCAL_YEAR'])
group_df.head()
# Define the columns of interest
CoI = ['GROSS_PROFIT', 'NET_PROFIT','CURR_RETL_PRICE']
#group_df = group_df.reset_index()
group_df.head()
#create_plots(group_df, 3, 'PRODUCT_CATEGORY_NAME','FISCAL_YEAR')
# Out:
#               GROSS_PROFIT     NET_PROFIT  CURR_RETL_PRICE
# FISCAL_YEAR
# 2017         271786.706424  192317.640035       122.583571
# 2018         206235.094095  175662.999620       132.370836
# 2019         222566.374912  190951.327806       137.812181

# %%
fig, ax = plt.subplots(ncols=3)
for col in range(len(group_df.columns)):
    sns.barplot(x=group_df.index, y=group_df.iloc[:, col], ax=ax[col])
    plt.tight_layout()

# %% [markdown]
# **2-2.Yearly Actual Sale vs Sale Estimate**
#
#
# *   Gross Sale Estimate is 10 time higher than actual profit.

# %%
monthly_sales_estimate['GROSS_SALES_ESTIMATE'] = monthly_sales_estimate['GROSS_SALES_ESTIMATE'].fillna('0')
monthly_sales_estimate['GROSS_SALES_ESTIMATE'] = monthly_sales_estimate['GROSS_SALES_ESTIMATE'].str.replace(',', '')
monthly_sales_estimate['GROSS_SALES_ESTIMATE'] = monthly_sales_estimate['GROSS_SALES_ESTIMATE'].str.replace('$', '')
monthly_sales_estimate['GROSS_SALES_ESTIMATE'] = monthly_sales_estimate['GROSS_SALES_ESTIMATE'].astype(int)
# Out:
# <ipython-input-36-b361802d4297>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   monthly_sales_estimate['GROSS_SALES_ESTIMATE'] = monthly_sales_estimate['GROSS_SALES_ESTIMATE'].str.replace('$', '')

# %%
monthly_sales_estimate.head()
# Out:
#   PRODUCT_CATEGORY_NAME  FISCAL_YEAR  FISCAL_MONTH_NBR FISCAL_MONTH_END_DT  \
# 0              SHINGLES         2017                 4          28 05 2017
# 1              SHINGLES         2017                 8          24 09 2017
# 2              SHINGLES         2017                 5          25 06 2017
# 3              SHINGLES         2017                 6          30 07 2017
# 4              SHINGLES         2017                 9          29 10 2017
#
#    GROSS_SALES_ESTIMATE
# 0              12000000
# 1              11900000
# 2              11700000
# 3              11100000
# 4              11000000

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
marketing_est_df = monthly_sales_estimate.groupby('FISCAL_YEAR').agg({'GROSS_SALES_ESTIMATE': 'mean'})
marketing_est_df.head()
# Out:
#              GROSS_SALES_ESTIMATE
# FISCAL_YEAR
# 2017                  2240089.583
# 2018                  2279692.708
# 2019                  2183436.250
# 2020                        0.000

# %%
df_esti_actual = pd.merge(group_df, marketing_est_df, how='left', on = 'FISCAL_YEAR')
df_esti_actual = df_esti_actual[['GROSS_SALES_ESTIMATE','GROSS_PROFIT']]
df_esti_actual = df_esti_actual.T

fig, ax = plt.subplots(nrows=3, figsize=(10, 20))
for col in range(len(group_df.columns)):
    sns.barplot(x=df_esti_actual.index, y=df_esti_actual.iloc[:, col], ax=ax[col])
    sns.set(style="whitegrid", font_scale=1)
    plt.tight_layout()

# %% [markdown]
# **2-3.Monthly Sale Trend**
#
#
# *   Gross profit tends to go up on May the most and Net profit was the best on October. We need to focus what kind of items are sold often during this time.

# %%
df_all.head()
# Out:
#   PRODUCT_ID PRODUCT_CATEGORY_NAME                        PRODUCT_NAME  \
# 0     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 1     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 2     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 3     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 4     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
#
#    CURR_RETL_PRICE  FISCAL_YEAR  FISCAL_MONTH_NBR  GROSS_SALES_QTY  \
# 0            3.890         2019                10            28488
# 1            3.890         2019                 4            37185
# 2            3.890         2018                 3            34340
# 3            3.890         2017                 9            31832
# 4            3.890         2017                 8            31956
#
#    NET_SALES_QTY  GROSS_PROFIT  NET_PROFIT
# 0          26951    110818.320  104839.390
# 1          35341    144649.650  137476.490
# ...

# %%
# Yearly sale trend
monthly_df = create_df(df_all, ['FISCAL_MONTH_NBR'])
monthly_df.head()
# Define the columns of interest
CoI = ['GROSS_PROFIT', 'NET_PROFIT','CURR_RETL_PRICE']
#group_df = group_df.reset_index()
monthly_df.head()
#create_plots(group_df, 3, 'PRODUCT_CATEGORY_NAME','FISCAL_YEAR')
# Out:
#                   GROSS_PROFIT  NET_PROFIT  CURR_RETL_PRICE
# FISCAL_MONTH_NBR
# 1                   161627.611  137886.634          123.583
# 2                   192062.124  164799.761          123.583
# 3                   213380.932  183507.469          128.268
# 4                   222793.113  187425.523          132.678
# 5                   390567.817  180632.963          131.948

# %%
fig, ax = plt.subplots(nrows=3, figsize=(20, 10))
for col in range(len(group_df.columns)):
    sns.lineplot(x=monthly_df.index, y=monthly_df.iloc[:, col], ax=ax[col])
    plt.tight_layout()

# %% [markdown]
# # **3. Monthly Sale Trend based on product categories**
#
#
# *   Based on monhtly analysis, it turned out shingles are popular all season but especially, in September and Gas snow bowlder is also popular in October.

# %%
df_all.head()
# Out:
#   PRODUCT_ID PRODUCT_CATEGORY_NAME                        PRODUCT_NAME  \
# 0     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 1     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 2     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 3     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
# 4     618170           SPRAY PAINT  PAINTERS TOUCH 2X SEMI-GLOSS WHITE
#
#    CURR_RETL_PRICE  FISCAL_YEAR  FISCAL_MONTH_NBR  GROSS_SALES_QTY  \
# 0            3.890         2019                10            28488
# 1            3.890         2019                 4            37185
# 2            3.890         2018                 3            34340
# 3            3.890         2017                 9            31832
# 4            3.890         2017                 8            31956
#
#    NET_SALES_QTY  GROSS_PROFIT  NET_PROFIT
# 0          26951    110818.320  104839.390
# 1          35341    144649.650  137476.490
# ...

# %%
# Yearly sale trend
cat_monthly_df = create_df(df_all, ['PRODUCT_CATEGORY_NAME','FISCAL_MONTH_NBR'])
cat_monthly_df.head()
# Define the columns of interest
CoI = ['GROSS_PROFIT', 'NET_PROFIT']
#group_df = group_df.reset_index()
cat_monthly_df.head()
cat_monthly_df = cat_monthly_df.reset_index()
#create_plots(group_df, 3, 'PRODUCT_CATEGORY_NAME','FISCAL_YEAR')

# %%
cat_monthly_df['PRODUCT_CATEGORY_NAME'].unique()
# Out:
# array(['1HDL KITCHEN FAUCETS', 'CABLE TIES', 'GAS SNOW BLOWERS',
#        'GLOVES,SAFETY APPAREL', 'PROJECT PANELS', 'SHINGLES',
#        'SPRAY PAINT', 'WALL TILE'], dtype=object)

# %%
cat_monthly_df[cat_monthly_df['PRODUCT_CATEGORY_NAME'] == 'GLOVES,SAFETY APPAREL']
# Out:
#     PRODUCT_CATEGORY_NAME  FISCAL_MONTH_NBR  GROSS_PROFIT  NET_PROFIT  \
# 36  GLOVES,SAFETY APPAREL                 1      2269.844    2214.778
# 37  GLOVES,SAFETY APPAREL                 2      3414.612    3342.159
# 38  GLOVES,SAFETY APPAREL                 3      5296.276    5183.262
# 39  GLOVES,SAFETY APPAREL                 4      6593.429    6455.109
# 40  GLOVES,SAFETY APPAREL                 5      5141.371    5011.641
# 41  GLOVES,SAFETY APPAREL                 6      3842.386    3736.350
# 42  GLOVES,SAFETY APPAREL                 7      3106.447    3024.432
# 43  GLOVES,SAFETY APPAREL                 8      2703.094    2627.934
# 44  GLOVES,SAFETY APPAREL                 9      2317.787    2250.811
# 45  GLOVES,SAFETY APPAREL                10      1776.007    1710.143
# 46  GLOVES,SAFETY APPAREL                11      1876.769    1825.518
# 47  GLOVES,SAFETY APPAREL                12      1818.574    1764.841
#
#     CURR_RETL_PRICE
# 36            3.292
# ...

# %%
def create_plots(df, num, cat, time):

    '''Create barplots for the specified dataframe'''
    # Define the subplots
    fig, ax = plt.subplots(nrows=num, figsize=(30, 20))
    #ax.get_xaxis().get_major_formatter().set_scientific(False)


    # Create the barplots
    for col in range(len(CoI)):
        sns.lineplot(x=cat, y=df[CoI[col]], hue= time, data=df, ax=ax[col])
        ax[col].set_xticklabels(labels=df[cat].unique(), rotation=45)
        ax[col].legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
        ax[col].set(xticks=df[cat].values)
        plt.tight_layout()

# %%
create_plots(cat_monthly_df,2,'FISCAL_MONTH_NBR','PRODUCT_CATEGORY_NAME')
# Out:
# <ipython-input-88-3e07c6f98498>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[col].set_xticklabels(labels=df[cat].unique(), rotation=45)
# <ipython-input-88-3e07c6f98498>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[col].set_xticklabels(labels=df[cat].unique(), rotation=45)

# %% [markdown]
# # **4. Forecasting new product**
#
#
# *   Based on general EDA, I found that snow blowers and shingles are for winter. so I chose these items trend as new product. Going to use time series model called prophet.

# %%
df_all
# Out:
#          GROSS_PROFIT
# DATE
# 2017-01  28263541.820
# 2017-02  33527488.080
# 2017-03  35484207.550
# 2017-04  41452619.490
# 2017-05 130606351.350
# 2017-06  38282223.230
# 2017-07  38760433.810
# 2017-08  45699298.370
# 2017-09  45741259.580
# 2017-10  42749159.310
# 2017-11  36996261.280
# 2017-12  28184862.630
# 2018-01  25422891.680
# 2018-02  27445483.020
# 2018-03  34428692.440
# 2018-04  35167906.980
# 2018-05  35691185.580
# 2018-06  33887311.940
# 2018-07  35241278.000
# 2018-08  42566535.720
# 2018-09  46660820.650
# 2018-10  49937119.150
# 2018-11  37299294.750
# 2018-12  30376353.160
# 2019-01  28582020.370
# 2019-02  36786649.770
# 2019-03  39551518.240
# 2019-04  38786305.840
# 2019-05  38359999.120
# 2019-06  40478054.640
# 2019-07  40232880.010
# 2019-08  44436849.980
# 2019-09  49240577.090
# 2019-10  55080835.430
# 2019-11  36862131.330
# 2019-12  32345547.990

# %%
df_winter = df_all[(df_all['PRODUCT_CATEGORY_NAME'] == 'SHINGLES')|(df_all['PRODUCT_CATEGORY_NAME'] == 'GAS SNOW BLOWERS')]
df_winter.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRODUCT_CATEGORY_NAME'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==1,'FISCAL_MONTH_NBR'] = '01'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==2,'FISCAL_MONTH_NBR'] = '02'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==3,'FISCAL_MONTH_NBR'] = '03'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==4,'FISCAL_MONTH_NBR'] = '04'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==5,'FISCAL_MONTH_NBR'] = '05'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==6,'FISCAL_MONTH_NBR'] = '06'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==7,'FISCAL_MONTH_NBR'] = '07'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==8,'FISCAL_MONTH_NBR'] = '08'
df_winter.loc[df_winter['FISCAL_MONTH_NBR'] ==9,'FISCAL_MONTH_NBR'] = '09'

# %%
df_winter = df_winter[['PRODUCT_ID','FISCAL_YEAR','FISCAL_MONTH_NBR','GROSS_PROFIT','FISCAL_MONTH_END_DT']]
df_winter['FISCAL_MONTH_NBR'] = df_winter['FISCAL_MONTH_NBR'].astype(str)
df_winter['FISCAL_YEAR'] = df_winter['FISCAL_YEAR'].astype(str)
df_winter['DATE'] = df_winter['FISCAL_YEAR'] + str('-') + df_winter['FISCAL_MONTH_NBR']
# Out:
# <ipython-input-155-7c0c66bce164>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_winter['FISCAL_MONTH_NBR'] = df_winter['FISCAL_MONTH_NBR'].astype(str)
# <ipython-input-155-7c0c66bce164>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_winter['FISCAL_YEAR'] = df_winter['FISCAL_YEAR'].astype(str)
# <ipython-input-155-7c0c66bce164>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
df_winter = df_winter.sort_values(by='DATE',ascending =True).reset_index(drop=True)
df_winter = df_winter[['PRODUCT_ID','DATE','GROSS_PROFIT']]
df_winter = df_winter.groupby('DATE').agg({'GROSS_PROFIT': 'mean'})

# %%
df_winter = df_winter.reset_index()

# %% [markdown]
# 2. Advantages of Prophet
# Table of Contents
#
# Prophet has several advantages associated with it. These are given below:-
#
# 1. Accurate and fast - Prophet is accurate and fast. It is used in many applications across Facebook for producing reliable forecasts for planning and goal setting.
# 2. Fully automatic - Prophet is fully automatic. We will get a reasonable forecast on messy data with no manual effort.
# 3. Tunable forecasts - Prophet produces adjustable forecasts. It includes many possibilities for users to tweak and adjust forecasts. We can use human-interpretable parameters to improve the forecast by adding our domain knowledge.
# 4. Available in R or Python - We can implement the Prophet procedure in R or Python.
# 5. Handles seasonal variations well - Prophet accommodates seasonality with multiple periods.
# 6. Robust to outliers - It is robust to outliers. It handles outliers by removing them.
# 7. Robust to missing data - Prophet is resilient to missing data.

# %%
df_winter.head()
# Out:
#       DATE  GROSS_PROFIT
# 0  2017-01    848981.176
# 1  2017-02   1060926.870
# 2  2017-03   1148406.637
# 3  2017-04   1383647.762
# 4  2017-05   1199928.611

# %%
df = df_winter.rename(columns={'DATE': 'ds',
                        'GROSS_PROFIT': 'y'})

df.head()
# Out:
#         ds           y
# 0  2017-01  848981.176
# 1  2017-02 1060926.870
# 2  2017-03 1148406.637
# 3  2017-04 1383647.762
# 4  2017-05 1199928.611

# %%
ax = df.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Monthly Number of Winter Product Sales')
ax.set_xlabel('Date')

plt.show()

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
import prophet as pr
my_model_winter = pr.Prophet(interval_width=0.95)
my_model_winter.fit(df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3f8907q8/tde5dolv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3f8907q8/1unchxni.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40713', 'data', 'file=/tmp/tmp3f8907q8/tde5dolv.json', 'init=/tmp/tmp3f8907q8/1unchxni.json', 'output', 'file=/tmp/tmp3f8907q8/prophet_modelp7ngek_t/prophet_model-20230723140059.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:00:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:01:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future_dates_winter = my_model_winter.make_future_dataframe(periods=12, freq='MS')
future_dates_winter.head()
# Out:
#           ds
# 0 2017-01-01
# 1 2017-02-01
# 2 2017-03-01
# 3 2017-04-01
# 4 2017-05-01

# %%
forecast_winter = my_model_winter.predict(future_dates_winter)
forecast_winter[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(12)
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 36 2020-01-01  799310.701  706198.323  892677.359
# 37 2020-02-01 1158736.795 1072125.920 1242668.468
# 38 2020-03-01 1183064.175 1091211.131 1271046.439
# 39 2020-04-01 1521232.200 1436627.216 1613434.218
# 40 2020-05-01 1282154.035 1198103.515 1375353.219
# 41 2020-06-01 1274663.840 1187951.236 1368573.659
# 42 2020-07-01 1340070.678 1255534.163 1430092.641
# 43 2020-08-01 1688570.229 1600650.336 1778401.543
# 44 2020-09-01 1626037.390 1531156.654 1715688.389
# 45 2020-10-01 1348358.651 1250588.184 1433854.156
# 46 2020-11-01 1228861.677 1134148.349 1324798.215
# 47 2020-12-01  933070.317  830615.909 1032163.099

# %%
my_model.plot(forecast, uncertainty=True)

# %% [markdown]
# **5. All product forecasting**

# %%
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==1,'FISCAL_MONTH_NBR'] = '01'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==2,'FISCAL_MONTH_NBR'] = '02'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==3,'FISCAL_MONTH_NBR'] = '03'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==4,'FISCAL_MONTH_NBR'] = '04'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==5,'FISCAL_MONTH_NBR'] = '05'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==6,'FISCAL_MONTH_NBR'] = '06'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==7,'FISCAL_MONTH_NBR'] = '07'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==8,'FISCAL_MONTH_NBR'] = '08'
df_all.loc[df_all['FISCAL_MONTH_NBR'] ==9,'FISCAL_MONTH_NBR'] = '09'

# %%
df_all = df_all[['PRODUCT_ID','FISCAL_YEAR','FISCAL_MONTH_NBR','GROSS_PROFIT','FISCAL_MONTH_END_DT']]
df_all['FISCAL_MONTH_NBR'] = df_all['FISCAL_MONTH_NBR'].astype(str)
df_all['FISCAL_YEAR'] = df_all['FISCAL_YEAR'].astype(str)
df_all['DATE'] = df_all['FISCAL_YEAR'] + str('-') + df_all['FISCAL_MONTH_NBR']
# Out:
# <ipython-input-180-252f8247b7d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['FISCAL_MONTH_NBR'] = df_all['FISCAL_MONTH_NBR'].astype(str)
# <ipython-input-180-252f8247b7d2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['FISCAL_YEAR'] = df_all['FISCAL_YEAR'].astype(str)
# <ipython-input-180-252f8247b7d2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_all = df_all.sort_values(by='DATE',ascending =True).reset_index(drop=True)
df_all = df_all[['PRODUCT_ID','DATE','GROSS_PROFIT']]
df_all = df_all.groupby('DATE').agg({'GROSS_PROFIT': 'sum'})

# %%
df_all_product = df_all_product.reset_index()

# %%
df_all_product = df_all_product.rename(columns={'DATE': 'ds',
                        'GROSS_PROFIT': 'y'})

df_all_product.head()
# Out:
#         ds             y
# 0  2017-01  28263541.820
# 1  2017-02  33527488.080
# 2  2017-03  35484207.550
# 3  2017-04  41452619.490
# 4  2017-05 130606351.350

# %%
ax = df_all_product.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Monthly Number of All Product Sales')
ax.set_xlabel('Date')

plt.show()

# %%
my_model = pr.Prophet(interval_width=0.95)
my_model.fit(df_all_product)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3f8907q8/fvjqhyij.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3f8907q8/fp3aumts.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24900', 'data', 'file=/tmp/tmp3f8907q8/fvjqhyij.json', 'init=/tmp/tmp3f8907q8/fp3aumts.json', 'output', 'file=/tmp/tmp3f8907q8/prophet_modelr7xbh0l5/prophet_model-20230723135533.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 13:55:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future_dates = my_model.make_future_dataframe(periods=12, freq='MS')
future_dates.head()
# Out:
#           ds
# 0 2017-01-01
# 1 2017-02-01
# 2 2017-03-01
# 3 2017-04-01
# 4 2017-05-01

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(12)
# Out:
#            ds          yhat    yhat_lower    yhat_upper
# 36 2020-01-01  22399617.565   5604715.865  37216821.135
# 37 2020-02-01  37747249.003  22001104.355  54090963.729
# 38 2020-03-01  16156073.941    220176.717  31541629.162
# 39 2020-04-01  18215636.177   3259949.458  33529854.814
# 40 2020-05-01 136285164.862 121321883.458 150644044.206
# 41 2020-06-01  14393954.561     27391.734  30112519.278
# 42 2020-07-01  20747581.599   5810864.488  36390880.933
# 43 2020-08-01  37739200.880  21658096.505  53194072.752
# 44 2020-09-01  44599580.629  28879272.050  59769454.863
# 45 2020-10-01  44809051.135  28062423.572  59753418.977
# 46 2020-11-01  49183810.092  33251945.094  64094421.963
# 47 2020-12-01  38201692.785  23009399.436  53287514.248

# %%
my_model.plot(forecast, uncertainty=True)

# %% [markdown]
# # **6. Conclusion**

# %%
#new product category
forecast_winter = forecast_winter[['ds', 'yhat']]
forecast_winter.columns = ['DATE','EXPECTED GROSS PROFIT']
forecast_winter
# Out:
#          DATE  EXPECTED GROSS PROFIT
# 0  2017-01-01             874249.234
# 1  2017-02-01            1034231.819
# 2  2017-03-01            1181383.487
# 3  2017-04-01            1367927.271
# 4  2017-05-01            1202223.672
# 5  2017-06-01            1196521.801
# 6  2017-07-01            1220367.026
# 7  2017-08-01            1490089.936
# 8  2017-09-01            1461247.147
# 9  2017-10-01            1221163.058
# 10 2017-11-01             958546.471
# 11 2017-12-01             703340.076
# 12 2018-01-01             695551.158
# 13 2018-02-01             914942.641
# 14 2018-03-01            1074096.987
# 15 2018-04-01            1152266.858
# 16 2018-05-01            1103066.987
# 17 2018-06-01            1140334.634
# 18 2018-07-01            1162504.339
# 19 2018-08-01            1396684.830
# 20 2018-09-01            1445074.907
# 21 2018-10-01            1281600.152
# 22 2018-11-01             918160.292
# 23 2018-12-01             745957.817
# ...

# %%
#all product category
forecast.columns = ['DATE','EXPECTED GROSS PROFIT']
forecast.tail(12)
# Out:
#          DATE  EXPECTED GROSS PROFIT
# 36 2020-01-01           22399617.565
# 37 2020-02-01           37747249.003
# 38 2020-03-01           16156073.941
# 39 2020-04-01           18215636.177
# 40 2020-05-01          136285164.862
# 41 2020-06-01           14393954.561
# 42 2020-07-01           20747581.599
# 43 2020-08-01           37739200.880
# 44 2020-09-01           44599580.629
# 45 2020-10-01           44809051.135
# 46 2020-11-01           49183810.092
# 47 2020-12-01           38201692.785
